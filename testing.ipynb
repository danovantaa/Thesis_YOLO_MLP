# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import torch

# %%
df = pd.read_csv("test.csv")
df.head()
# Out:
#         NamaFile   Label
# 0  test_0000.jpg  Sedang
# 1  test_0001.jpg  Sedang
# 2  test_0002.jpg  Sedang
# 3  test_0003.jpg  Sedang
# 4  test_0004.jpg  Sedang
